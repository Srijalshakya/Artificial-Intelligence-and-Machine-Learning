# %%
# !pip install pillow
# Out:
# Requirement already satisfied: pillow in /usr/local/lib/python3.11/dist-packages (11.1.0)

# %%
from PIL import Image

# %% [markdown]
# #Exercise 1

# %%
image_colored = Image.open("/content/drive/MyDrive/Artificial Intelligence and Machine Learning/lenna_image.png")

# %%
print("Format:",image_colored.format)
print("Mode:",image_colored.mode)
print("Size:",image_colored.size)
# Out:
# Format: PNG
# Mode: RGBA
# Size: (366, 357)

# %%
image_colored = image_colored.convert("RGB")
print(image_colored.mode)
# Out:
# RGB

# %%
image_grayed = image_colored.convert('L')
display(image_grayed)
# Out:
# <PIL.Image.Image image mode=L size=366x357>

# %%
width, height = image_colored.size
channels = len(image_colored.getbands())

print(f"Image shape (RGB): ({height}, {width}, {channels})")

image_size_colored = width * height * 1
print(f"Image size (RGB): {image_size_colored}")
# Out:
# Image shape (RGB): (357, 366, 3)
# Image size (RGB): 130662

# %%
width, height = image_grayed.size
channels = len(image_grayed.getbands())

print(f"Image shape (gray): ({height}, {width},{channels})")

image_size_colored = width * height * 3
print(f"Image size (RGB): {image_size_colored}")
# Out:
# Image shape (gray): (357, 366,1)
# Image size (RGB): 391986

# %%
import numpy as np
image_array_colored = np.array(image_colored)
image_array_colored.shape
# Out:
# (357, 366, 3)

# %%
image_array_grayed = np.array(image_grayed)
image_array_grayed.shape
# Out:
# (357, 366)

# %%
# Convert the image to grayscale (if not already)
image_gray = image_colored.convert("L")

# Convert to NumPy array
image_array = np.array(image_gray)

# Modify the top-left 100x100 pixels to a value of 210 (light gray)
image_array[:100, :100] = 210

# Display the modified image
plt.figure(figsize=(6, 6))
plt.imshow(image_array, cmap='gray')
plt.title('Modified Image with Top-left 100x100 Pixels Set to 210')
plt.axis('off')  # Hide the axes
plt.show()

# %%
red_channel = image_array_colored[:,:,0] #Red Channel
print(red_channel)
display(red_channel)
# Out:
# [[225 224 226 ...  92  90  91]
#  [225 224 224 ...  91  90  91]
#  [223 223 224 ...  93  91  91]
#  ...
#  [ 88  92  95 ... 148 162 175]
#  [ 88  92  96 ... 154 168 177]
#  [254 254 254 ... 255 255 255]]
# array([[225, 224, 226, ...,  92,  90,  91],
#        [225, 224, 224, ...,  91,  90,  91],
#        [223, 223, 224, ...,  93,  91,  91],
#        ...,
#        [ 88,  92,  95, ..., 148, 162, 175],
#        [ 88,  92,  96, ..., 154, 168, 177],
#        [254, 254, 254, ..., 255, 255, 255]], dtype=uint8)

# %%
red_channel = image_array_colored.copy()
red_channel [ : , : , 1] = 0
red_channel [ : , : , 2] = 0
print(red_channel)
display(red_channel)
# Out:
# [[[225   0   0]
#   [224   0   0]
#   [226   0   0]
#   ...
#   [ 92   0   0]
#   [ 90   0   0]
#   [ 91   0   0]]
#
#  [[225   0   0]
#   [224   0   0]
#   [224   0   0]
#   ...
#   [ 91   0   0]
#   [ 90   0   0]
#   [ 91   0   0]]
#
#  [[223   0   0]
#   [223   0   0]
#   [224   0   0]
#   ...
#   [ 93   0   0]
#   [ 91   0   0]
#   [ 91   0   0]]
#
#  ...
#
#  [[ 88   0   0]
#   [ 92   0   0]
#   [ 95   0   0]
#   ...
#   [148   0   0]
#   [162   0   0]
#   [175   0   0]]
#
#  [[ 88   0   0]
#   [ 92   0   0]
#   [ 96   0   0]
#   ...
#   [154   0   0]
#   [168   0   0]
#   [177   0   0]]
#
#  [[254   0   0]
#   [254   0   0]
#   [254   0   0]
#   ...
#   [255   0   0]
#   [255   0   0]
#   [255   0   0]]]
# array([[[225,   0,   0],
#         [224,   0,   0],
#         [226,   0,   0],
#         ...,
#         [ 92,   0,   0],
#         [ 90,   0,   0],
#         [ 91,   0,   0]],
#
#        [[225,   0,   0],
#         [224,   0,   0],
#         [224,   0,   0],
#         ...,
#         [ 91,   0,   0],
#         [ 90,   0,   0],
#         [ 91,   0,   0]],
#
#        [[223,   0,   0],
#         [223,   0,   0],
#         [224,   0,   0],
#         ...,
#         [ 93,   0,   0],
#         [ 91,   0,   0],
#         [ 91,   0,   0]],
#
#        ...,
#
#        [[ 88,   0,   0],
#         [ 92,   0,   0],
#         [ 95,   0,   0],
#         ...,
#         [148,   0,   0],
#         [162,   0,   0],
#         [175,   0,   0]],
#
#        [[ 88,   0,   0],
#         [ 92,   0,   0],
#         [ 96,   0,   0],
#         ...,
#         [154,   0,   0],
#         [168,   0,   0],
#         [177,   0,   0]],
#
#        [[254,   0,   0],
#         [254,   0,   0],
#         [254,   0,   0],
#         ...,
#         [255,   0,   0],
#         [255,   0,   0],
#         [255,   0,   0]]], dtype=uint8)

# %%
green_channel = image_array_colored.copy()
green_channel [ : , : , 2] = 0
green_channel [ : , : , 0] = 0
print(green_channel)
display(green_channel)
# Out:
# [[[  0 127   0]
#   [  0 130   0]
#   [  0 130   0]
#   ...
#   [  0  25   0]
#   [  0  23   0]
#   [  0  17   0]]
#
#  [[  0 130   0]
#   [  0 128   0]
#   [  0 130   0]
#   ...
#   [  0  22   0]
#   [  0  22   0]
#   [  0  20   0]]
#
#  [[  0 128   0]
#   [  0 133   0]
#   [  0 129   0]
#   ...
#   [  0  25   0]
#   [  0  22   0]
#   [  0  17   0]]
#
#  ...
#
#  [[  0  23   0]
#   [  0  22   0]
#   [  0  26   0]
#   ...
#   [  0  57   0]
#   [  0  68   0]
#   [  0  66   0]]
#
#  [[  0  26   0]
#   [  0  27   0]
#   [  0  26   0]
#   ...
#   [  0  63   0]
#   [  0  71   0]
#   [  0  66   0]]
#
#  [[  0 254   0]
#   [  0 254   0]
#   [  0 254   0]
#   ...
#   [  0 255   0]
#   [  0 255   0]
#   [  0 255   0]]]
# array([[[  0, 127,   0],
#         [  0, 130,   0],
#         [  0, 130,   0],
#         ...,
#         [  0,  25,   0],
#         [  0,  23,   0],
#         [  0,  17,   0]],
#
#        [[  0, 130,   0],
#         [  0, 128,   0],
#         [  0, 130,   0],
#         ...,
#         [  0,  22,   0],
#         [  0,  22,   0],
#         [  0,  20,   0]],
#
#        [[  0, 128,   0],
#         [  0, 133,   0],
#         [  0, 129,   0],
#         ...,
#         [  0,  25,   0],
#         [  0,  22,   0],
#         [  0,  17,   0]],
#
#        ...,
#
#        [[  0,  23,   0],
#         [  0,  22,   0],
#         [  0,  26,   0],
#         ...,
#         [  0,  57,   0],
#         [  0,  68,   0],
#         [  0,  66,   0]],
#
#        [[  0,  26,   0],
#         [  0,  27,   0],
#         [  0,  26,   0],
#         ...,
#         [  0,  63,   0],
#         [  0,  71,   0],
#         [  0,  66,   0]],
#
#        [[  0, 254,   0],
#         [  0, 254,   0],
#         [  0, 254,   0],
#         ...,
#         [  0, 255,   0],
#         [  0, 255,   0],
#         [  0, 255,   0]]], dtype=uint8)

# %%
blue_channel = image_array_colored.copy()
blue_channel [ : , : , 0] = 0
blue_channel [ : , : , 1] = 0
print(blue_channel)
display(blue_channel)
# Out:
# [[[  0   0 110]
#   [  0   0 106]
#   [  0   0 105]
#   ...
#   [  0   0  64]
#   [  0   0  62]
#   [  0   0  56]]
#
#  [[  0   0 110]
#   [  0   0 104]
#   [  0   0 114]
#   ...
#   [  0   0  64]
#   [  0   0  61]
#   [  0   0  63]]
#
#  [[  0   0 105]
#   [  0   0 114]
#   [  0   0 111]
#   ...
#   [  0   0  67]
#   [  0   0  65]
#   [  0   0  61]]
#
#  ...
#
#  [[  0   0  58]
#   [  0   0  58]
#   [  0   0  60]
#   ...
#   [  0   0  78]
#   [  0   0  84]
#   [  0   0  78]]
#
#  [[  0   0  58]
#   [  0   0  61]
#   [  0   0  61]
#   ...
#   [  0   0  83]
#   [  0   0  85]
#   [  0   0  77]]
#
#  [[  0   0 254]
#   [  0   0 254]
#   [  0   0 254]
#   ...
#   [  0   0 255]
#   [  0   0 255]
#   [  0   0 255]]]
# array([[[  0,   0, 110],
#         [  0,   0, 106],
#         [  0,   0, 105],
#         ...,
#         [  0,   0,  64],
#         [  0,   0,  62],
#         [  0,   0,  56]],
#
#        [[  0,   0, 110],
#         [  0,   0, 104],
#         [  0,   0, 114],
#         ...,
#         [  0,   0,  64],
#         [  0,   0,  61],
#         [  0,   0,  63]],
#
#        [[  0,   0, 105],
#         [  0,   0, 114],
#         [  0,   0, 111],
#         ...,
#         [  0,   0,  67],
#         [  0,   0,  65],
#         [  0,   0,  61]],
#
#        ...,
#
#        [[  0,   0,  58],
#         [  0,   0,  58],
#         [  0,   0,  60],
#         ...,
#         [  0,   0,  78],
#         [  0,   0,  84],
#         [  0,   0,  78]],
#
#        [[  0,   0,  58],
#         [  0,   0,  61],
#         [  0,   0,  61],
#         ...,
#         [  0,   0,  83],
#         [  0,   0,  85],
#         [  0,   0,  77]],
#
#        [[  0,   0, 254],
#         [  0,   0, 254],
#         [  0,   0, 254],
#         ...,
#         [  0,   0, 255],
#         [  0,   0, 255],
#         [  0,   0, 255]]], dtype=uint8)

# %% [markdown]
# Extracting Colored Channels Using PIL

# %%
r, g, b = image_colored.split()
display(r)
display(g)
display(b)
# Out:
# <PIL.Image.Image image mode=L size=366x357>
# <PIL.Image.Image image mode=L size=366x357>
# <PIL.Image.Image image mode=L size=366x357>

# %%
row_100 = image_array_colored[100,:,:]
print(row_100)
# Out:
# [[169  63  76]
#  [166  65  75]
#  [170  64  76]
#  ...
#  [210 132 122]
#  [209 133 116]
#  [208 134 126]]

# %%
col_50 = image_array_colored[:,50,:]
print(col_50)
# Out:
# [[160  61  82]
#  [163  63  82]
#  [166  61  74]
#  ...
#  [ 82  19  67]
#  [ 79  18  66]
#  [254 254 254]]

# %%
pixel = image_array_colored[100,100,:]
print(pixel)
# Out:
# [201  84  84]

# %%
left = 100
upper = 50
right = 200
lower = 150
cropped_image = image_colored . crop ((left, upper , right , lower))
display(cropped_image)
# Out:
# <PIL.Image.Image image mode=RGB size=100x100>

# %% [markdown]
# Saving NUmPy Array to image.

# %%
image_array = np. zeros ((100, 100, 3) , dtype = np.uint8)
image_from_array = Image . fromarray (image_array)
image_from_array . show ()

# %%
display(image_from_array)
# Out:
# <PIL.Image.Image image mode=RGB size=100x100>

# %%
image_from_array.save("output_image.jpg")

# %%
image_array = np.random.randint(0, 256, (100, 100, 3), dtype=np.uint8)
image_from_array = Image.fromarray(image_array)
image_from_array.show()
display(image_from_array)
# Out:
# <PIL.Image.Image image mode=RGB size=100x100>

# %% [markdown]
# #Exercise 2

# %% [markdown]
# PCA for Image Compression

# %%
import numpy as np
import matplotlib.pyplot as plt
from PIL import Image

image = Image.open("/content/drive/MyDrive/Artificial Intelligence and Machine Learning/camera_man.jpg").convert("L")

image_array = np.array(image)
print(image_array.shape)

height,width = image_array.shape

data = image_array.copy()

plt.imshow(image_array, cmap ='gray')
plt.show()
# Out:
# (325, 220)

# %%
# Load the image
image = Image.open("/content/drive/MyDrive/Artificial Intelligence and Machine Learning/camera_man.jpg").convert("L")  # Convert to grayscale
image_array = np.array(image)

# Get the dimensions of the image
height, width = image_array.shape

# Calculate the center coordinates
start_x = (width - 150) // 2
start_y = (height - 150) // 2

# Extract the middle 150x150 section
middle_section = image_array[start_y:start_y+150, start_x:start_x+150]

# Display the cropped image
plt.imshow(middle_section, cmap='gray')
plt.title("Middle 150x150 Section")
plt.axis('off')
plt.show()

# %%
# Apply threshold: set pixel values below 100 to 0, and above 100 to 255
thresholded_image = np.where(image_array < 100, 0, 255)

# Display the binary image
plt.imshow(thresholded_image, cmap='gray')
plt.title("Thresholded Image")
plt.axis('off')
plt.show()

# %%
# Rotate the image array 90 degrees clockwise
rotated_image_array = np.rot90(image_array, k=-1)

# Display the rotated image
plt.imshow(rotated_image_array, cmap='gray')
plt.title("Rotated 90 Degrees Clockwise")
plt.axis('off')
plt.show()

# %%
# Convert grayscale image to RGB by replicating grayscale values across all three channels
rgb_image = np.stack([image_array] * 3, axis=-1)

# Display the RGB image
plt.imshow(rgb_image)
plt.title("Grayscale to RGB Image")
plt.axis('off')
plt.show()

# %% [markdown]
# #Exercise 3

# %%
import numpy as np
import matplotlib.pyplot as plt
from PIL import Image

image = Image.open("/content/drive/MyDrive/Artificial Intelligence and Machine Learning/camera_man.jpg").convert("L")

image_array = np.array(image)
print(image_array.shape)

height, width = image_array.shape

# data = image_array.reshape(height, width)
data = image_array.copy()

plt.imshow(image_array, cmap='gray')
plt.show()
# Out:
# (325, 220)

# %% [markdown]
# Computing Mean of eaxh column

# %%
mean = np.mean(data, axis = 0)

centered_data = data - mean

# %%
centered_data.shape
# Out:
# (325, 220)

# %%
cov_matrix = np.cov(centered_data,rowvar=False)

# %%
cov_matrix.shape
# Out:
# (220, 220)

# %%
eigenvalues , eigenvectors = np.linalg.eigh(cov_matrix)

sorted_indices = np.argsort(eigenvalues)[::-1]
eigenvalues = eigenvalues[sorted_indices]
eigenvectors = eigenvectors[:, sorted_indices]

# %%
explained_variance_ratio = eigenvalues / np . sum (eigenvalues)
plt.plot (np . cumsum (explained_variance_ratio))
plt.title(" Cumulative Explained Variance")
plt.xlabel("numabers of compoents")
plt.ylabel("Cumulative Explained Variance")
plt.grid (True)
plt.show()

# %%
k = 60
components = eigenvectors[:, : k]

# %%
compressed_data = np.dot (centered_data, components)

# %%
decompressed_data = np.dot (compressed_data, components . T) + mean

# %%
plt.figure (figsize = (12, 6))

plt.subplot(1,3,1)
plt.imshow(image_array, cmap='gray')
plt.title("Original Image")
plt.axis("off")

plt.subplot (1,3,2)
plt.imshow(compressed_data, cmap="gray", aspect="auto")
plt.title(f"Compressed Image (k={k})")
plt.axis ("off")

plt.subplot (1,3,3)
plt.imshow(decompressed_data, cmap="gray")
plt.title("Decompressed Image")
plt.axis("off")
plt.tight_layout()
plt.show()
